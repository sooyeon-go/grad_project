# %%
import pandas as pd
import numpy as np

# %%
import csv

# %%
f = open('n_comment1_csv.csv','r', encoding = 'cp949')
rdr = csv.reader(f)
for line in rdr:
    print(line)
f.close()
# Out:
# ['comment', 'label']
# ['말투 깬다', '1']
# ['요즘 연앤들 싫은소린 아에 차단하고 듣기좋은소리만 들으려하는듯. 조금만 비판해도 악플러 법적대응이라니 돈써서 본인들이 위라는행동 참 ㅋ 오래가겠다', '1']
# ['저 짧은 몇 마디에서 인성이 보이넴 ..', '1']
# ['개념없어 원래도 비호감 이었지만 하는 행동이나 말투 밉상 그자체ㅋㅋㅋㅋㅋ', '1']
# ['정신분열 잼 ㅋㅋㅋ', '1']
# ['실력에비해 오래갔다', '1']
# ['거만이 하늘을 찌르네. 뭔짓을 하든 묻지도 따지지도 말고 찬양만 하고 돈이나 바쳐라 이건가?', '1']
# ['점점... 왜저러냐 리더라는게 맨날 표정관리 못하고 기분에 따라 행동하고말하는거 진짜 별로다', '1']
# ['말하는거 저급해...', '1']
# ['말투가 왜저래ㅋㅋ', '1']
# ['아무리 그래도 그렇지 말투가 저게 뭐냐;', '1']
# ['왜저래 비꼰데?? 힘들면 그냥 조용히 탈퇴하세요~ 요즘 보면 얼굴도 어둡고 기분대로 행동하고 표정 다 드러내더만 이제 내리막길 ..다들 얼굴에 생기가 없고 초심도 잃은거 같고 ..배부르지?? 그만하고 쉬어라 다들 ..팬 많지? 금방 썰물처럼 다 휩쓸려간다 ~너희 아무것도 아니다~ 배부른 소리하고 자빠졌네 ~비호감이네 진짜', '1']
# ['아무리봐도 잘못 뽑은 것 같다', '1']
# ['인기있을때 높은곳에 있을 때 말을 좀 조심할 필요가 있을 거 같네요 표현이 참;;;', '1']
# ['인기도 좋고 다 좋은데 말투가 왜 그래요 어린 팬들도 많은 사람이', '1']
# ['진짜 예민하네;', '1']
# ['와...좀 깨긴 깬다 스트레스여서 그럴 수도 있는데 그래도 라이브 동영상에서 저런 말을 했다는게....당신이 그 자리에 앉아있는 것도 그런 관심 때문인 것을....ㅉㅉ', '1']
# ['윽..진짜 말투 이런다고???', '1']
# ...

# %%
dic = pd.read_csv('n_comment1_csv.csv',encoding = 'cp949')
dic
# Out:
#                                                comment  label
# 0                                                말투 깬다      1
# 1    요즘 연앤들 싫은소린 아에 차단하고 듣기좋은소리만 들으려하는듯. 조금만 비판해도 악...      1
# 2                               저 짧은 몇 마디에서 인성이 보이넴 ..      1
# 3             개념없어 원래도 비호감 이었지만 하는 행동이나 말투 밉상 그자체ㅋㅋㅋㅋㅋ      1
# 4                                           정신분열 잼 ㅋㅋㅋ      1
# ..                                                 ...    ...
# 739                             돼지효 또 사고침?하여튼 못생긴것들이 꼭      1
# 740                                     뭐믿고 말투 그따구냐???      1
# 741                      말투는 급식체 아직도 중2병걸렸나? 걍 성숙치못하다.      1
# 742                                               은퇴해라      1
# 743                                  설리 따라가거라~~~~~~~~       1
#
# [744 rows x 2 columns]

# %%
f = open('p_comment5_csv.csv','r', encoding = 'cp949')
rdr = csv.reader(f)
for line in rdr:
    print(line)
f.close()
# Out:
# ['comment', 'label']
# ['정말 노래 대단하네요', '0']
# ['가창력 대단하고.인기도  굉장해요.연예계의 별이 될꺼 같아요', '0']
# ['노래만큼은  정말    넘사벽  맞다.   최고  맞다.  ', '0']
# ['진짜 잘하네용', '0']
# ['노래 정말잘해', '0']
# ['티비 보는데 진짜 잘하긴 잘하네요', '0']
# ['소름돋네요.  방송사에서 이케 파격대우하다니. 아무나 해주지 않쵸.', '0']
# ['정말 타고났다는 말밖엔 표현할 방법이없다 대박이다 대박', '0']
# ['지금 콘서트 방송 보고있는데 진짜 최고', '0']
# ['신곡  좋네요', '0']
# ['정말 대단합니다.~~엄청난 임팩트  . 카리스마  대단해요.~~', '0']
# ['직접 보진 못했지만 방송으로 설겆이도 미뤄둔채 본방사수중입니다, 들을수록 정이가는 음색입니다.꾸준하게 열심히 노래 부러세요~~^^', '0']
# ['다른 가수 저 레파토리로 할수있는 사람없다 퀄리티좀봐라', '0']
# ['정말 연예계의 별이네요 가창력도 대단하시고 너무 멋있으세요 카리스마도 엄청나시고 얼굴도 복스럽게 생기셔서 나이 상관없이 모두에게 사랑받으시는거같아요 존경합니다', '0']
# ['최고네요', '0']
# ['와~~팬덤 장난 아이네요 노래도 정말 잘하구요', '0']
# ['노래 정말 정말 잘하는 가수가 나타났다 짱 멋집니다', '0']
# ['신곡 넘 좋아요. 완전팬 되었습니다.', '0']
# ['노래 천재', '0']
# ['와..진짜  티비 보면서도 울었습니다.백만녀만에  한번 나올까말까 한 가수라는게 맞는듯', '0']
# ['mbc 신경좀 썼네!! 감동이다!!!!', '0']
# ['너무 잘하네요. 신곡도 너무좋고 ?넘 좋음ㆍ너무 인상도좋고  사랑스러움', '0']
# ['울컥. 대박 기원', '0']
# ['역사에 한획을 그은 가수임에 틀림없다..가슴이 아리다.. 음색에는  뭔가 특별한 뭔가가 있다...', '0']
# ...

# %%
dic2 = pd.read_csv('p_comment5_csv.csv',encoding = 'cp949')
dic2
# Out:
#                                comment  label
# 0                          정말 노래 대단하네요      0
# 1    가창력 대단하고.인기도  굉장해요.연예계의 별이 될꺼 같아요      0
# 2    노래만큼은  정말    넘사벽  맞다.   최고  맞다.        0
# 3                              진짜 잘하네용      0
# 4                              노래 정말잘해      0
# ..                                 ...    ...
# 809                    대한민국에 전설이될가수다 .      0
# 810           품위 있게 당신의 글은 곧 당신의 품격입니다      0
# 811                              사랑합니다      0
# 812                            잘한다 잘해요      0
# 813          역대급 최고에 가수. 사랑합니다????????      0
#
# [814 rows x 2 columns]

# %%
fi = dic.append(dic2)
fi
# Out:
#                                                comment  label
# 0                                                말투 깬다      1
# 1    요즘 연앤들 싫은소린 아에 차단하고 듣기좋은소리만 들으려하는듯. 조금만 비판해도 악...      1
# 2                               저 짧은 몇 마디에서 인성이 보이넴 ..      1
# 3             개념없어 원래도 비호감 이었지만 하는 행동이나 말투 밉상 그자체ㅋㅋㅋㅋㅋ      1
# 4                                           정신분열 잼 ㅋㅋㅋ      1
# ..                                                 ...    ...
# 809                                    대한민국에 전설이될가수다 .      0
# 810                           품위 있게 당신의 글은 곧 당신의 품격입니다      0
# 811                                              사랑합니다      0
# 812                                            잘한다 잘해요      0
# 813                          역대급 최고에 가수. 사랑합니다????????      0
#
# [1558 rows x 2 columns]

# %%
f = open('n_comment3_csv.csv','r', encoding = 'cp949')
rdr = csv.reader(f)
for line in rdr:
    print(line)
f.close()
# Out:
# ['comment', 'label']
# ['인간아 왜 사니?', '1']
# ['못생긴거는 어디서 꿀리지 않는 사람인데 너보니 위안이된다 진짜 못생겼다 너', '1']
# ['관상은 과학이다', '1']
# ['진짜 좆같네', '1']
# ['으휴 한심하다 한심해 ㅉㅉㅉㅉ', '1']
# ['개찐따야 나가 뒤졌으면 좋겠어', '1']
# ['쟨 그냥 전형적인 일베 찐따더라', '1']
# ['욕 오지게 먹고 정신 좀 차려라  ㅡㅡ', '1']
# ['생긴것 부터가 또라이같더라 니부모는 니가 얼마나 쪽팔리겠어.', '1']
# ['꼴뚜기 같은게 꼴깝떨고 앉았네', '1']
# ['얼굴 개 혐오스럽데토 나와', '1']
# ['왜 안죽어?', '1']
# ['키작고.. 이마 넓고.. 문둥이 눈썹..좁은 어깨..긴 얼굴..썪은얼굴 .. 못생긴 얼굴 대표 나가면 1등 할듯', '1']
# ['찐따 색기 저거 ㅋㅋ', '1']
# ['똑똑한척 씨부리는 꼴이 더 멍청해 보이는군', '1']
# ['너 주변엔 사람이 없어?', '1']
# ['어디서 짖니', '1']
# ['뭔 개소리야. ', '1']
# ['정신장애 있는 분 같은데..', '1']
# ['아직 안죽었어??죽길 바랐는데 아쉽네..???죽어~', '1']
# ['못생긴 꼴뚜기 새끼야~~', '1']
# ['돼지새끼', '1']
# ['정신과  치료나  받아...', '1']
# ['진짜 수준보여', '1']
# ['방송보면서 구역질 나오긴 처음이다. 생긴 것도 그지같은게 말도 그지같이 해', '1']
# ['이 쭈꾸미새끼는 뭐지 어휴 진짜 이런 존못도 오랜만에 본다ㅋㅋㅋㅋㅋㅋ', '1']
# ['마스크가 혹성탈출급인디 ㅋㅋㅋ', '1']
# ['진짜  더럽게 생겼다', '1']
# ['외모비하 아닙니다 거울좀 보세요', '1']
# ['헛소리를 정성들여 하네 ㅡㅡ ', '1']
# ['저 얼굴로 살아가는게 용하다', '1']
# ...

# %%
dic3 = pd.read_csv('n_comment3_csv.csv',encoding = 'cp949')
dic3
# Out:
#                                        comment  label
# 0                                    인간아 왜 사니?      1
# 1    못생긴거는 어디서 꿀리지 않는 사람인데 너보니 위안이된다 진짜 못생겼다 너      1
# 2                                     관상은 과학이다      1
# 3                                       진짜 좆같네      1
# 4                             으휴 한심하다 한심해 ㅉㅉㅉㅉ      1
# ..                                         ...    ...
# 458                         뇌가 텅텅 비어있는 것 같은데..      1
# 459                    시발롬아 이럴거면 그냥 죽어 공기가 아깝다      1
# 460                                 한강 가서 재기해~      1
# 461                             정말 개돼지들은 답이 없다      1
# 462                         난 쟤가 목매달고 자살했음 좋겠다      1
#
# [463 rows x 2 columns]

# %%
fi2 = fi.append(dic3)
fi2
# Out:
#                                                comment  label
# 0                                                말투 깬다      1
# 1    요즘 연앤들 싫은소린 아에 차단하고 듣기좋은소리만 들으려하는듯. 조금만 비판해도 악...      1
# 2                               저 짧은 몇 마디에서 인성이 보이넴 ..      1
# 3             개념없어 원래도 비호감 이었지만 하는 행동이나 말투 밉상 그자체ㅋㅋㅋㅋㅋ      1
# 4                                           정신분열 잼 ㅋㅋㅋ      1
# ..                                                 ...    ...
# 458                                 뇌가 텅텅 비어있는 것 같은데..      1
# 459                            시발롬아 이럴거면 그냥 죽어 공기가 아깝다      1
# 460                                         한강 가서 재기해~      1
# 461                                     정말 개돼지들은 답이 없다      1
# 462                                 난 쟤가 목매달고 자살했음 좋겠다      1
#
# [2021 rows x 2 columns]

# %%
f = open('n_comment2_csv.csv','r', encoding = 'cp949')
rdr = csv.reader(f)
for line in rdr:
    print(line)
f.close()
# Out:
# ['comment', 'label']
# ['약을너무해서 제정신들은 아닌듯', '1']
# ['씨이이이발 얼굴 보고 싶지도 않아 토나와', '1']
# ['야야 ', '1']
# ['정신건강에 안좋네요. 더이상 이사람 기사화 안했으면 좋겠어요', '1']
# ['또시작이네 관종똘아이 관심못받으면 환각증세라도오니?', '1']
# ['범죄자 새끼', '1']
# ['또라이년아 안뒤지고 뭐하는거야????', '1']
# ['정신이 이상해져가는게 아니라 원래 이상햇어 ㅋㅋ', '1']
# ['연극성 성격장애', '1']
# ['얜 SNS 없으면 인생 무슨 재미로 살았을려나.. 걍 모든걸 다 SNS화 시키네', '1']
# ['진심... 관종이란게 이런 사람을 두고 하는 이야기임', '1']
# ['탑오브관종', '1']
# ['이 녀석들은 두더쥐인가? 잊을만 하면 기어나오네', '1']
# ['확실한건 제정신은 아님', '1']
# ['부모도 돌았고 다들 ㅋ 와아. 나라꼬라지참.', '1']
# ['한남처럼 하고다니더니 한남화 된건가', '1']
# ['남녀 성을 떠나서 인간으로써 이상함', '1']
# ['관종이다 아주. 뭐 어쩌라구~', '1']
# ['듣보잡 관심없다 당장 내려라 참 말세다. 청소년들한테 안좋다', '1']
# ['나이가 어린것도 아닌데 왜 이리 헤메냐...이젠 불쌍하기까지하다야', '1']
# ['엄마도  이상해..', '1']
# ['느그 엄마가 너 낳고 미역국 먹을 생각했다니 끔찍하다야', '1']
# ['역시 엄마도 제정신이 아닌거야', '1']
# ['야 정신병자야', '1']
# ['계속 나오는거보면 스폰이 있는거같은데..', '1']
# ['정신병자들은 제발 정신병원에 입원시키자...........', '1']
# ['저 관종 진짜 별거다하네', '1']
# ['....희대의 관종', '1']
# ...

# %%
dic4 = pd.read_csv('n_comment2_csv.csv',encoding = 'cp949')
dic4
# Out:
#                                    comment  label
# 0                         약을너무해서 제정신들은 아닌듯      1
# 1                   씨이이이발 얼굴 보고 싶지도 않아 토나와      1
# 2                                      야야       1
# 3        정신건강에 안좋네요. 더이상 이사람 기사화 안했으면 좋겠어요      1
# 4             또시작이네 관종똘아이 관심못받으면 환각증세라도오니?      1
# ..                                     ...    ...
# 526                   xx는거 찍은 동영상 나옴  대박칠듯      1
# 527                            드러...ㅠ눈 버렸네      1
# 528                         니 조개에 싸다구 날릴거여      1
# 529                                 자살해야지?      1
# 530  정신병자 새끼야..........안뒤지고 뭐하노 제발 좀 나가 죽길      1
#
# [531 rows x 2 columns]

# %%
fi3 = fi2.append(dic4)
fi3
# Out:
#                                                comment  label
# 0                                                말투 깬다      1
# 1    요즘 연앤들 싫은소린 아에 차단하고 듣기좋은소리만 들으려하는듯. 조금만 비판해도 악...      1
# 2                               저 짧은 몇 마디에서 인성이 보이넴 ..      1
# 3             개념없어 원래도 비호감 이었지만 하는 행동이나 말투 밉상 그자체ㅋㅋㅋㅋㅋ      1
# 4                                           정신분열 잼 ㅋㅋㅋ      1
# ..                                                 ...    ...
# 526                               xx는거 찍은 동영상 나옴  대박칠듯      1
# 527                                        드러...ㅠ눈 버렸네      1
# 528                                     니 조개에 싸다구 날릴거여      1
# 529                                             자살해야지?      1
# 530              정신병자 새끼야..........안뒤지고 뭐하노 제발 좀 나가 죽길      1
#
# [2552 rows x 2 columns]

# %%
f = open('p_comment1_csv.csv','r', encoding = 'cp949')
rdr = csv.reader(f)
for line in rdr:
    print(line)
f.close()
# Out:
# ['comment', 'label']
# ['다정의 의인화~ 항상 세심하게 주변사람 챙기고, 늘 본인보다도 팬들 걱정하는 따뜻한 사람인거 팬들과 스탭분들 다 아는 사실이죠. 안보이는데서 더 진심과 최선을 다하는게 그저 대단하고 대견할 뿐입니다. 더 사랑받고 더더 인정받는 20년이 되었음 좋겠네요. 사랑해', '0']
# ['항상 같이 고생한 스텝분들 꼭 챙기고 수상소감 말할때 언급해주고~ 참 따뜻하고 맑고 ... 포근해 ^^ 언제나 늘 응원한다', '0']
# ['다정하고 배려심 넘치고 속깊고 따뜻한 진국으로 유명하지 얼굴 만큼 마음씨도 잘생긴 멋진 아티스트 한순간도 진심 아니였던적이 아닌적이 없는 멋진 사람 늘 진심으로 챙기고 배려하는게 눈에 보여서 감동이야 스텝분이 부럽다 보이지 않는곳에서 더 열심히 하고 팬들과 스텝분들 챙길줄 아는 진국 2020년에는  소망하는 모든일이 이루어지길 바란다 사랑해', '0']
# ['너는 정말 따뜻하고 소중한 사람이야', '0']
# ['배려의아이콘', '0']
# ['멋진 외모 ', '0']
# ['지극한 팬사랑부터 겸손하고 배려심넘치고 초심을잃지않고  최선을다해 변함없이 노력하는구나', '0']
# ['멋진 사람이다 정말', '0']
# ['존경합니다', '0']
# ['겸손과 배려가 넘치는 인성갑', '0']
# ['그 누가 세게 흔들어도 우린 널 절대 놓지 않을꺼야.', '0']
# ['사랑해 좋은것만 보고가자', '0']
# ['귀여우면서도 어느새 어른스럽고 한거 너무너무 기특하고 사랑해', '0']
# ['잘난척도 나대지도 않는 뼛속까지 진국인 사람', '0']
# ['천사같은 사람', '0']
# ['어떻게 이런 사람이 우리 곁에 왔을까', '0']
# ['사랑스러운 사람 ', '0']
# ['언제나 뒤에서 응원할게', '0']
# ['사랑하고 또 사랑해', '0']
# ['얼굴도 너무너무 멋지고 인성도 너무너무 멋져 몸도 너무너무 좋아', '0']
# ['너무너무 멋져', '0']
# ...

# %%
dic5 = pd.read_csv('p_comment1_csv.csv',encoding = 'cp949')
dic5
# Out:
#                                                comment  label
# 0    다정의 의인화~ 항상 세심하게 주변사람 챙기고, 늘 본인보다도 팬들 걱정하는 따뜻한...      0
# 1    항상 같이 고생한 스텝분들 꼭 챙기고 수상소감 말할때 언급해주고~ 참 따뜻하고 맑고...      0
# 2    다정하고 배려심 넘치고 속깊고 따뜻한 진국으로 유명하지 얼굴 만큼 마음씨도 잘생긴 ...      0
# 3                                  너는 정말 따뜻하고 소중한 사람이야      0
# 4                                               배려의아이콘      0
# ..                                                 ...    ...
# 240                                       따뜻함이 느껴지는 모습      0
# 241                                      요즘 보기 드문 사람일세      0
# 242                                           초콜렛같은 사람      0
# 243                   머리를 길러도 멋있고 잘라도 멋있고 뭘하건 다 멋있는 사람      0
# 244                                       내가 너무넘무 좋아해요      0
#
# [245 rows x 2 columns]

# %%
fi4 = fi3.append(dic5)
fi4
# Out:
#                                                comment  label
# 0                                                말투 깬다      1
# 1    요즘 연앤들 싫은소린 아에 차단하고 듣기좋은소리만 들으려하는듯. 조금만 비판해도 악...      1
# 2                               저 짧은 몇 마디에서 인성이 보이넴 ..      1
# 3             개념없어 원래도 비호감 이었지만 하는 행동이나 말투 밉상 그자체ㅋㅋㅋㅋㅋ      1
# 4                                           정신분열 잼 ㅋㅋㅋ      1
# ..                                                 ...    ...
# 240                                       따뜻함이 느껴지는 모습      0
# 241                                      요즘 보기 드문 사람일세      0
# 242                                           초콜렛같은 사람      0
# 243                   머리를 길러도 멋있고 잘라도 멋있고 뭘하건 다 멋있는 사람      0
# 244                                       내가 너무넘무 좋아해요      0
#
# [2797 rows x 2 columns]

# %%
f = open('n_comment6_csv.csv','r', encoding = 'cp949')
rdr = csv.reader(f)
for line in rdr:
    print(line)
f.close()
# Out:
# ['comment', 'label']
# ['관종..?', '1']
# ['가슴도 없던데 ?ㅋㅋ', '1']
# ['얜진짜 관종이야 ..', '1']
# ['잊을만 하면 지랄해서 검색어에 이름 올리는거지,.. 관심병걸린 왕따들이 한번 시선끌려할때 엄청 세게 꼴값떨고 웃고는 잊혀질만하면 또 한번씩 세게 꼴값떨고 다니지', '1']
# ['혼자 즐겨라 애들도 다보는데 머하냐 ㅉㅉ', '1']
# ['싸보이는 배우 1위', '1']
# ['아 진짜 얘도 구혜선처럼 피곤함', '1']
# ['인기가 없으니 별짓 다하는구나.', '1']
# ['천박한게  연예인이라고~참 한심하다살아가는 방법도 가지가지', '1']
# ['야동 배우 하고 싶어하는듯싶다.', '1']
# ['구혜선한테 밀린다는 느낌을 받은건가?', '1']
# ['에휴 아이들이  이런 연예인들을 티브이 에서 보지않길 바래요...', '1']
# ['저사람은 부모 가족도 없는건지...   왜 저러고 다니지?  저 사람도 법적 제제좀 가해야돼가족들이 불쌍하다', '1']
# ['좀 애가 이상해~', '1']
# ['본디 사람은 배워야하는 법..... 보고배운게 없니왜...ㅜㅜ 책좀읽고 교양과 상식좀 키우자..', '1']
# ['볼거도 없더만 자꾸 왜이러냐', '1']
# ['바바리맨이랑 너랑 다를게 뭐냐', '1']
# ['이사람은 가족이 없나? 부끄러운줄아세요!', '1']
# ['정신상태가 이상함. 노출증임', '1']
# ['빤스랑 옷은 왜 입고 다니냐... 걍 벗고 다니지', '1']
# ['걍 다 벗고 살죠~~~~정상 맞나요???역겨움', '1']
# ['시선 가게 쳐만들어 놓고 시선 강간 하지 마라...?? 얘 개념 수준...!!', '1']
# ['얘가  성장 환경이  그래서 인가   애정 결핍이 강한것같네', '1']
# ['관종을 넘어 살짝 변태기질다분함', '1']
# ['애정결핍 아님??ㅋㅋㅋㅋ변태 애정결핍', '1']
# ['죽어라', '1']
# ...

# %%
dic6 = pd.read_csv('n_comment6_csv.csv',encoding = 'cp949')
dic6
# Out:
#                                                comment  label
# 0                                                관종..?      1
# 1                                          가슴도 없던데 ?ㅋㅋ      1
# 2                                          얜진짜 관종이야 ..      1
# 3    잊을만 하면 지랄해서 검색어에 이름 올리는거지,.. 관심병걸린 왕따들이 한번 시선끌...      1
# 4                               혼자 즐겨라 애들도 다보는데 머하냐 ㅉㅉ      1
# ..                                                 ...    ...
# 474                                               역겨워요      1
# 475                                        곧 밑에도 보여주냐?      1
# 476                            그냥 벗어줘 ㅋㅋㅋ근데 절벽이라 볼게없다ㅜ      1
# 477                                       가슴 이쁘니까 괜찮아~      1
# 478                                  마인드쓰레기인거 지금안거아니자나      1
#
# [479 rows x 2 columns]

# %%
fi5 = fi4.append(dic6)
fi5
# Out:
#                                                comment  label
# 0                                                말투 깬다      1
# 1    요즘 연앤들 싫은소린 아에 차단하고 듣기좋은소리만 들으려하는듯. 조금만 비판해도 악...      1
# 2                               저 짧은 몇 마디에서 인성이 보이넴 ..      1
# 3             개념없어 원래도 비호감 이었지만 하는 행동이나 말투 밉상 그자체ㅋㅋㅋㅋㅋ      1
# 4                                           정신분열 잼 ㅋㅋㅋ      1
# ..                                                 ...    ...
# 474                                               역겨워요      1
# 475                                        곧 밑에도 보여주냐?      1
# 476                            그냥 벗어줘 ㅋㅋㅋ근데 절벽이라 볼게없다ㅜ      1
# 477                                       가슴 이쁘니까 괜찮아~      1
# 478                                  마인드쓰레기인거 지금안거아니자나      1
#
# [3276 rows x 2 columns]

# %%
f = open('p_comment2_csv.csv','r', encoding = 'cp949')
rdr = csv.reader(f)
for line in rdr:
    print(line)
f.close()
# Out:
# ['comment', 'label']
# ['진짜 사람을 집중시키는 힘이 있고 충분한 매력이 보였어요 ', '0']
# ['성격도 좋고 성숙한 마인드가 깃들여져 있더라 ', '0']
# ['진짜 앞으로도 오래도록 계속 될꺼 같네요 응원합니다', '0']
# ['말 한 마디, 한 마디에서 긍정적인 마인드와 배려와 진중함과 진심이 가득 느껴지는 참 바르고 배울 점이 많아보이네', '0']
# ['배려가 깊음이 데뷔때부터 한결같이 느껴지네요.', '0']
# ['즐거운 일만 가득하고 늘 웃는 날만 있었으면 좋겠네요.', '0']
# ['성숙한 마인드와 인성이 훌륭하다고 생각한다', '0']
# ['다정하게 말하는거보면 항상 배워야겠다고 생각하게된다', '0']
# ['너무 많은 힐링이 되는 존재입니다', '0']
# ['너무 소중하고 귀해 사랑해!!! ', '0']
# ['매순간 한결같이  진심이 묻어나는 마음이 참 예쁘고 귀하네요 ^^ ', '0']
# ['아름다운사람', '0']
# ['저런 마인드가 좋다 쉽지 않은 일인데 항상 긍정적으로 관계를 소중하게 생각 한다 ', '0']
# ['외모에 반비례하는 성숙미를 가지고 있네', '0']
# ['존경스럽다', '0']
# ['웃는모습보면 얼마나 진솔한 사람인가 알게됩니다. ', '0']
# ['진짜 너무너무 소중해요', '0']
# ['우리나라에서 제일 열심히 사는듯', '0']
# ['말과 행동은 그자체로 힐링과 감동을 주네', '0']
# ['화려한 미사어구나 과장이 없이 오롯이 날것 그대로의 진심이 전해지네요', '0']
# ['긍정적인 마인드 좋아합니다', '0']
# ['내면이 아름답고 당연 가장 눈길가는 사람이더군요. ', '0']
# ['사랑해~', '0']
# ['언제나 응원하고 잇어', '0']
# ['너무 소중해', '0']
# ['능력치가 진짜 끝도 없네요 요줌 하나만하기에도 벅찬데 진짜 열이면 열 백이면 백 다 잘하는듯', '0']
# ...

# %%
dic7 = pd.read_csv('p_comment2_csv.csv',encoding = 'cp949')
dic7
# Out:
#                                                comment  label
# 0                     진짜 사람을 집중시키는 힘이 있고 충분한 매력이 보였어요       0
# 1                            성격도 좋고 성숙한 마인드가 깃들여져 있더라       0
# 2                         진짜 앞으로도 오래도록 계속 될꺼 같네요 응원합니다      0
# 3    말 한 마디, 한 마디에서 긍정적인 마인드와 배려와 진중함과 진심이 가득 느껴지는 ...      0
# 4                            배려가 깊음이 데뷔때부터 한결같이 느껴지네요.      0
# ..                                                 ...    ...
# 397                                        믿어지지 않는 실력       0
# 398                                             생각도 깊어      0
# 399                                          존재만으로도 행복      0
# 400                                      항상 모든 것을 응원할게      0
# 401                                              행복만하길      0
#
# [402 rows x 2 columns]

# %%
fi6 = fi5.append(dic7)
fi6
# Out:
#                                                comment  label
# 0                                                말투 깬다      1
# 1    요즘 연앤들 싫은소린 아에 차단하고 듣기좋은소리만 들으려하는듯. 조금만 비판해도 악...      1
# 2                               저 짧은 몇 마디에서 인성이 보이넴 ..      1
# 3             개념없어 원래도 비호감 이었지만 하는 행동이나 말투 밉상 그자체ㅋㅋㅋㅋㅋ      1
# 4                                           정신분열 잼 ㅋㅋㅋ      1
# ..                                                 ...    ...
# 397                                        믿어지지 않는 실력       0
# 398                                             생각도 깊어      0
# 399                                          존재만으로도 행복      0
# 400                                      항상 모든 것을 응원할게      0
# 401                                              행복만하길      0
#
# [3678 rows x 2 columns]
